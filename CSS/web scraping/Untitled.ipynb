# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('http://finance.daum.net')

# %%
response.headers
# Out:
# {'Date': 'Tue, 21 Aug 2018 07:42:35 GMT', 'Server': 'Apache', 'Expires': 'Fri, 01 Jan 1990 00:00:00 GMT', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'Set-Cookie': 'PREMIUMCHK=""; Domain=.finance.daum.net; Path=/, PREMIUM=""; Domain=.finance.daum.net; Path=/', 'Content-Language': 'ko-KR', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '12964', 'Connection': 'close', 'Content-Type': 'text/html;charset=utf-8'}

# %%
response.text
# Out:
# '<!doctype html>\n\t\t\t\n\n\n\n\n\n\n\n\n\n\n    \n            \n    \n\n\n                        \n\n<html lang="ko">\n<head>\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t<meta name="verify-v1" content="iXgHW7UooMcyeiV/Zb0Tk/yK2yB+IuA5/5GgIzGBEns=" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=10">\n    <meta property="og:image" content="https://t1.daumcdn.net/finance/old/img/thumb-img.png"/>     <meta property="og:site_name" content="다음 금융">\n    <meta property="og:title" content="다음 금융">\n    <title>Daum 금융</title>\n\t\t<link rel="shortcut icon" href="http://finance.daum.net/favicon.ico" type="image/x-icon" />\n\t<link rel="icon" href="http://finance.daum.net/favicon.ico" type="image/x-icon" />\n\t<link rel="stylesheet" type="text/css" href="http://t1.daumcdn.net/finance/old/stock/css/newHeader.css?ver=20180605190000" />\n\t<link rel="stylesheet" type="text/css" href="/css/stockTop2014.css?ver=20180605190000" />\n\t<!--[if lt IE 9]>\n\t<scri
# ...

# %%
response = requests.get('http://finance.daum.net')
html = response.text
html
# Out:
# '<!doctype html>\n\t\t\t\n\n\n\n\n\n\n\n\n\n\n    \n            \n    \n\n\n                        \n\n<html lang="ko">\n<head>\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t<meta name="verify-v1" content="iXgHW7UooMcyeiV/Zb0Tk/yK2yB+IuA5/5GgIzGBEns=" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=10">\n    <meta property="og:image" content="https://t1.daumcdn.net/finance/old/img/thumb-img.png"/>     <meta property="og:site_name" content="다음 금융">\n    <meta property="og:title" content="다음 금융">\n    <title>Daum 금융</title>\n\t\t<link rel="shortcut icon" href="http://finance.daum.net/favicon.ico" type="image/x-icon" />\n\t<link rel="icon" href="http://finance.daum.net/favicon.ico" type="image/x-icon" />\n\t<link rel="stylesheet" type="text/css" href="http://t1.daumcdn.net/finance/old/stock/css/newHeader.css?ver=20180605190000" />\n\t<link rel="stylesheet" type="text/css" href="/css/stockTop2014.css?ver=20180605190000" />\n\t<!--[if lt IE 9]>\n\t<scri
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')
soup.find('ul', attrs={'class': 'list_category'})
# Out:
# <ul class="list_category">
# <!-- if 1 -->
# <!-- if 1.1 -->
# <li>
# <span class="subtit_category"><a class="ellipsis_g" href="/quote/upjong_detail.daum?stype=P&amp;seccode=024&amp;nil_profile=stocktop&amp;nil_menu=nstock76">증권</a></span>
# <span class="num_percent factor_up">+3.21%</span>
# <span class="name_company">
# <span class="txt_company"><a class="ellipsis_g link_company" href="/item/main.daum?code=030210">KTB투자증권</a></span>
# <span class="ico_financetop factor_up">up</span>
# </span>
# </li>
# <!-- if 1.2 -->
# <li>
# <span class="subtit_category"><a class="ellipsis_g" href="/quote/upjong_detail.daum?stype=P&amp;seccode=013&amp;nil_profile=stocktop&amp;nil_menu=nstock77">전기전자</a></span>
# <span class="num_percent factor_up">+2.70%</span>
# <span class="name_company">
# <span class="txt_company"><a class="ellipsis_g link_company" href="/item/main.daum?code=001820">삼화콘덴서</a></span>
# <span class="ico_financetop factor_up">up</span>
# </span>
# </li>
# <!-- if 1.3 -->
# <li>
# ...

# %%
base_url = "http://finance.daum.net/exchange/exchangeDetail.daum?code="
ex_code = ['USD', 'GBP', 'JPY']

for
